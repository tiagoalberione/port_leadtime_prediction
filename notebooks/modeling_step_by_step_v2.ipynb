# %% [markdown]
# # Modelagem do Capitulo 4 - versao v2
#
# Este notebook e a trilha didatica da reconstrṳ̣o canonica com features historicas temporalmente seguras. O codigo pesado vive em `scripts/run_cap4_rebuild.py`; os resultados reproduziveis ficam em `results/cap4_rebuild/`.

# %%
from pathlib import Path
import pandas as pd
RESULTS = Path('..') / 'results' / 'cap4_rebuild'
FIGURES = RESULTS / 'figures'

# %% [markdown]
# ## 1. Preparacao e temporal leakage

# %% [markdown]
# Texto interpretativo preenchido a partir de `results/cap4_rebuild/report.md`.

# %% [markdown]
# ## 2. Catalogo das features

# %%
pd.read_csv(RESULTS / 'feature_catalog.csv').head(20)

# %% [markdown]
# ## 3. Divisao temporal

# %% [markdown]
# Texto interpretativo preenchido a partir de `results/cap4_rebuild/report.md`.

# %% [markdown]
# ## 4. Baselines

# %%
pd.read_csv(RESULTS / 'baseline_reproduction.csv').head(20)

# %% [markdown]
# ## 5. Ridge

# %% [markdown]
# Texto interpretativo preenchido a partir de `results/cap4_rebuild/report.md`.

# %% [markdown]
# ## 6. Random forest

# %% [markdown]
# Texto interpretativo preenchido a partir de `results/cap4_rebuild/report.md`.

# %% [markdown]
# ## 7. Gradient boosting

# %% [markdown]
# Texto interpretativo preenchido a partir de `results/cap4_rebuild/report.md`.

# %% [markdown]
# ## 8. Hgb

# %% [markdown]
# Texto interpretativo preenchido a partir de `results/cap4_rebuild/report.md`.

# %% [markdown]
# ## 9. Comparacao pontual

# %%
pd.read_csv(RESULTS / 'point_model_comparison_validation.csv').head(20)

# %% [markdown]
# ## 10. Analise da cauda

# %%
pd.read_csv(RESULTS / 'tail_comparison.csv').head(20)

# %% [markdown]
# ## 11. Regressao quantilica

# %%
pd.read_csv(RESULTS / 'quantile_model_comparison.csv').head(20)

# %% [markdown]
# ## 12. Comparacao com incerteza historica

# %%
pd.read_csv(RESULTS / 'uncertainty_global.csv').head(20)

# %% [markdown]
# ## 13. Analise intragrupo

# %%
pd.read_csv(RESULTS / 'uncertainty_within_group.csv').head(20)

# %% [markdown]
# ## 14. Valor incremental das familias de features

# %%
pd.read_csv(RESULTS / 'contextual_ablation.csv').head(20)

# %% [markdown]
# ## 15. Simulacao de estoque de seguranca

# %%
pd.read_csv(RESULTS / 'safety_stock_simulation.csv').head(20)

# %% [markdown]
# ## 16. Sintese

# %%
pd.read_csv(RESULTS / 'bootstrap_results.csv').head(20)

# %%
print((RESULTS / 'report.md').read_text(encoding='utf-8'))
