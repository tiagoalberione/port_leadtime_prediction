# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)

# %load_ext autoreload
# %autoreload 2
# Out:
# g:\My Drive\Graduação e Pós\USP\MBA USP IA e Big Data\TCC\port_leadtime_prediction

# %%
import pandas as pd

from src.config.paths import RAW_ESTADIA_DIR
from src.ingestion.load_estadia import load_estadia_files
from src.processing.process_estadia import process_estadia

# %%
df_estadia_raw = load_estadia_files(input_dir=RAW_ESTADIA_DIR)

print(df_estadia_raw.shape)
# Out:
# (162036, 24)

# %%
df_estadia_raw
# Out:
#               DUV    Porto - Bitrigrama  \
# 0           12022   BRSSZ
# 1           22022   BRSSZ
# 2           32022   BRSSZ
# 3           62022   BRRJ022
# 4           72022   BRMEA001
# ...           ...                   ...
# 162031  610152025                 BRNTR
# 162032  610182025                 BRRIO
# 162033  610312025                 BRRIO
# 162034  610382025                 BRRIO
# 162035  610772025                 BRRIO
#
#                                              Porto - Nome Embarcacao - IMO  \
# 0        SANTOS                                       ...          9634854
# 1        SANTOS                                       ...          9699359
# 2        SANTOS                                       ...          9686273
# 3        PORTO DO AÇU                                 ...          9644158
# 4        TERMINAL PETROBRÁS - MACAÉ - RJ              ...          9618757
# ...                                                   ...              ...
# ...

# %%
df_estadia_raw.drop_duplicates()
# Out:
#               DUV    Porto - Bitrigrama  \
# 0           12022   BRSSZ
# 1           22022   BRSSZ
# 2           32022   BRSSZ
# 3           62022   BRRJ022
# 4           72022   BRMEA001
# ...           ...                   ...
# 162031  610152025                 BRNTR
# 162032  610182025                 BRRIO
# 162033  610312025                 BRRIO
# 162034  610382025                 BRRIO
# 162035  610772025                 BRRIO
#
#                                              Porto - Nome Embarcacao - IMO  \
# 0        SANTOS                                       ...          9634854
# 1        SANTOS                                       ...          9699359
# 2        SANTOS                                       ...          9686273
# 3        PORTO DO AÇU                                 ...          9644158
# 4        TERMINAL PETROBRÁS - MACAÉ - RJ              ...          9618757
# ...                                                   ...              ...
# ...

# %%
df_estadia_processed = process_estadia(df_estadia_raw)

print(df_estadia_processed.shape)
df_estadia_processed.head()
# Out:
# (162036, 24)
#      duv    porto_-_bitrigrama  \
# 0  12022   BRSSZ
# 1  22022   BRSSZ
# 2  32022   BRSSZ
# 3  62022   BRRJ022
# 4  72022   BRMEA001
#
#                                         porto_-_nome embarcacao_-_imo  \
# 0   SANTOS                                       ...          9634854
# 1   SANTOS                                       ...          9699359
# 2   SANTOS                                       ...          9686273
# 3   PORTO DO AÇU                                 ...          9644158
# 4   TERMINAL PETROBRÁS - MACAÉ - RJ              ...          9618757
#
#      embarcacao_-_inscricao                      embarcacao_-_nome  \
# 0                             ORION GLOBE
# 1                             COPENHAGEN EAGLE
# 2                             CEPHEUS OCEAN
# 3                             ZARAPITO
# 4                3813885801    MAR LIMPO II
#
#    tripulantes_-_embarque  tripulantes_-_transito  tripulantes_-_desembarque  \
# ...
