# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)

# %load_ext autoreload
# %autoreload 2
# Out:
# g:\My Drive\Graduação e Pós\USP\MBA USP IA e Big Data\TCC\port_leadtime_prediction

# %%
import pandas as pd

import src.config.paths as paths
from src.ingestion.load_estadia import load_estadia_files
from src.processing.process_estadia import process_estadia

from src.ingestion.load_porto import load_porto_files
from src.processing.process_porto import process_porto

from src.ingestion.load_meteorologia import load_meteorologia_files
from src.processing.process_meteorologia import process_meteorologia

# %%
df_estadia_raw = load_estadia_files(input_dir=paths.RAW_ESTADIA_DIR)
df_estadia_processed = process_estadia(df_estadia_raw)
df_estadia_processed
# Out:
#               duv porto_bitrigrama                       porto_nome  \
# 0           12022            BRSSZ                           SANTOS
# 1           22022            BRSSZ                           SANTOS
# 2           32022            BRSSZ                           SANTOS
# 3           62022          BRRJ022                     PORTO DO AÇU
# 4           72022         BRMEA001  TERMINAL PETROBRÁS - MACAÉ - RJ
# ...           ...              ...                              ...
# 162031  610152025            BRNTR                          NITERÓI
# 162032  610182025            BRRIO                   RIO DE JANEIRO
# 162033  610312025            BRRIO                   RIO DE JANEIRO
# 162034  610382025            BRRIO                   RIO DE JANEIRO
# 162035  610772025            BRRIO                   RIO DE JANEIRO
#
#         embarcacao_imo embarcacao_inscricao  \
# 0            9634854.0                  NaN
# 1            9699359.0                  NaN
# ...

# %%
df_estadia_processed.drop_duplicates(inplace=True)
df_estadia_processed
# Out:
#               duv porto_bitrigrama                       porto_nome  \
# 0           12022            BRSSZ                           SANTOS
# 1           22022            BRSSZ                           SANTOS
# 2           32022            BRSSZ                           SANTOS
# 3           62022          BRRJ022                     PORTO DO AÇU
# 4           72022         BRMEA001  TERMINAL PETROBRÁS - MACAÉ - RJ
# ...           ...              ...                              ...
# 162031  610152025            BRNTR                          NITERÓI
# 162032  610182025            BRRIO                   RIO DE JANEIRO
# 162033  610312025            BRRIO                   RIO DE JANEIRO
# 162034  610382025            BRRIO                   RIO DE JANEIRO
# 162035  610772025            BRRIO                   RIO DE JANEIRO
#
#         embarcacao_imo embarcacao_inscricao  \
# 0            9634854.0                  NaN
# 1            9699359.0                  NaN
# ...

# %%
df_porto_raw = load_porto_files(input_dir=paths.RAW_PORTO_DIR)
df_porto_processed = process_porto(df_porto_raw)

df_porto_processed
# Out:
#         porto                                         nome_porto  \
# 0    BR052001                         TERMINAL FLUVIAL DE JURUTI
# 1    BR147001               TERMINAL PORTUÁRIO FLUVIAL - COPESUL
# 2    BR252002  TERM AQUAVIARIO DE GUAMARE - 3R OPERAÇÕES MARI...
# 3    BR302002                                            TUP NSR
# 4    BR400001       TERMINAL DE MINERIO FERROPORT - PORTO DO AÇU
# ..        ...                                                ...
# 120   BRSE003                   CELSE TERMINAL DE REGASEIFICAÇÃO
# 121  BRSFS002                              TERMINAL DA BABITONGA
# 122  BRVDC004              TERMINAL FLUVIAL RIO CAPIM CAULIM S/A
# 123     BRVLL                                    PORTO DE LAGUNA
# 124   BRBA004                              TERMINAL DE CARAVELAS
#
#                    cidade estado    regiao   latitude  longitude
# 0                  JURITI     PA     NORTE  -2.173782 -56.105980
# ...

# %%
df_meteorologia_raw = load_meteorologia_files(input_dir=paths.RAW_METEOROLOGIA_DIR)
df_meteorologia_processed = process_meteorologia(df_meteorologia_raw)

df_meteorologia_processed
# Out:
#          latitude  longitude        date  temperature_2m_mean  \
# 0       -2.173782 -56.105980  2021-06-15                 26.7
# 1       -2.173782 -56.105980  2021-06-16                 26.4
# 2       -2.173782 -56.105980  2021-06-17                 26.8
# 3       -2.173782 -56.105980  2021-06-18                 27.1
# 4       -2.173782 -56.105980  2021-06-19                 26.9
# ...           ...        ...         ...                  ...
# 167094 -12.753888 -38.624305  2025-08-27                 23.4
# 167095 -12.753888 -38.624305  2025-08-28                 24.0
# 167096 -12.753888 -38.624305  2025-08-29                 24.0
# 167097 -12.753888 -38.624305  2025-08-30                 23.7
# 167098 -12.753888 -38.624305  2025-08-31                 23.6
#
#         temperature_2m_max  temperature_2m_min  precipitation_sum  rain_sum  \
# 0                     30.2                24.3                6.1       6.1
# ...
