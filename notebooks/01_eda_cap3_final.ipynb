# %% [markdown]
# # EDA final do Capítulo 3
#
# Este notebook reproduz, de forma enxuta e independente do EDA original, as evidências exploratórias que permanecem no Capítulo 3 da monografia. Ele parte da base analítica final `data/processed/eda_base.parquet`, valida o recorte utilizado no estudo e gera as quatro figuras finais do capítulo.
#
# O notebook antigo `notebooks/01_eda_ptbr.ipynb` permanece como referência histórica do projeto, mas não é necessário para executar esta reprodução.

# %% [markdown]
# ## 1. Configuração
#
# Imports, caminhos relativos ao repositório, parâmetros gráficos e funções auxiliares pequenas usadas pelas quatro figuras.

# %%
from pathlib import Path
import shutil
import sys
import warnings

import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
from matplotlib.ticker import FuncFormatter
import numpy as np
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

DATA_PATH = PROJECT_ROOT / "data" / "processed" / "eda_base.parquet"
OUTPUT_DIR = PROJECT_ROOT / "outputs" / "capitulo3"
MONOGRAFIA_IMG_DIR = PROJECT_ROOT.parent / "mba-tcc-monografia" / "USPSC-img"

TARGET_H = "t_total_port_stay_h"
DATE_COL = "arrival_port_ts"
PORT_LABEL_COL = "port_display_ref"
EXPECTED_N = 129_625
EXPECTED_START = pd.Timestamp("2023-01-01")
EXPECTED_END = pd.Timestamp("2025-12-31")
REFERENCE_STATS_DAYS = {
    "media_d": 2.96,
    "mediana_d": 1.60,
    "p90_d": 6.80,
    "p95_d": 10.57,
}

COMPONENT_COLUMNS = {
    "t_wait_for_berthing_h": "Espera para atracação",
    "t_operation_h": "Operação atracada",
    "t_post_operation_h": "Pós-operação",
    "t_total_port_stay_h": "Permanência total",
}

OPERATION_LABELS = {
    "op_abastecimento_bunker": "Abastecimento (bunker)",
    "op_arribada": "Arribada",
    "op_carga": "Carga",
    "op_descarga": "Descarga",
    "op_desembarque_passageiros": "Desembarque de passageiros",
    "op_embarque_passageiros": "Embarque de passageiros",
    "op_fundeio": "Fundeio",
    "op_fundeio_ship_to_ship": "Fundeio ship-to-ship",
    "op_navio_estado_com_operacao_comercial": "Navio de Estado com operação comercial",
    "op_navio_estado_marinha_brasil": "Navio de Estado - Marinha do Brasil",
    "op_navio_estado_sem_operacao_comercial": "Navio de Estado sem operação comercial",
    "op_offshore": "Offshore",
    "op_reparo_manutencao": "Reparo/manutenção",
    "op_retirada_residuos_com_operacao_comercial": "Retirada de resíduos com operação comercial",
    "op_retirada_residuos_sem_operacao_comercial": "Retirada de resíduos sem operação comercial",
    "op_solicitacao_certificado": "Solicitação de certificado",
    "op_tipo_operacao_nao_mapeado": "Tipo de operação não mapeado",
}

plt.rcParams.update({
    "figure.dpi": 120,
    "savefig.dpi": 300,
    "font.size": 9,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 8,
    "figure.facecolor": "white",
    "axes.facecolor": "white",
    "axes.spines.top": False,
    "axes.spines.right": False,
})

COLOR_TOTAL = "#2f5d7c"
COLOR_MEDIAN = "#3b6f58"
COLOR_P90 = "#b06f2a"
COLOR_GRID = "#d9dde2"
COLOR_BOX = "#8fb3c8"
COLOR_MAP = "#4c78a8"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


def fmt_decimal_pt(value, decimals=2):
    """Formata números com vírgula decimal para leitura das tabelas do capítulo."""
    if pd.isna(value):
        return ""
    return f"{value:,.{decimals}f}".replace(",", "X").replace(".", ",").replace("X", ".")


def fmt_axis_days(value, _position=None):
    """Formata eixos em dias sem expor nomes técnicos de colunas."""
    return fmt_decimal_pt(value, 0)


def relpath(path):
    """Mostra caminhos relativos ao repositório quando possível."""
    path = Path(path)
    try:
        return path.relative_to(PROJECT_ROOT).as_posix()
    except ValueError:
        return path.as_posix()


def save_figure(fig, stem):
    """Salva uma figura em PDF vetorial e PNG 300 dpi no diretório do Capítulo 3."""
    pdf_path = OUTPUT_DIR / f"{stem}.pdf"
    png_path = OUTPUT_DIR / f"{stem}.png"
    fig.savefig(pdf_path, bbox_inches="tight")
    fig.savefig(png_path, bbox_inches="tight", dpi=300)
    plt.close(fig)
    return pdf_path, png_path


def stats_for_series(series_h):
    """Calcula estatísticas resumidas em horas e dias a partir de uma série em horas."""
    clean_h = series_h.dropna()
    clean_d = clean_h / 24
    return {
        "n": int(clean_h.shape[0]),
        "media_h": clean_h.mean(),
        "mediana_h": clean_h.median(),
        "p90_h": clean_h.quantile(0.90),
        "p95_h": clean_h.quantile(0.95),
        "p99_h": clean_h.quantile(0.99),
        "media_d": clean_d.mean(),
        "mediana_d": clean_d.median(),
        "p90_d": clean_d.quantile(0.90),
        "p95_d": clean_d.quantile(0.95),
        "p99_d": clean_d.quantile(0.99),
    }

# %% [markdown]
# ## 2. Carregamento e validação da base
#
# A fonte analítica final é `data/processed/eda_base.parquet`, construída pelo pipeline oficial do projeto. Cada linha representa uma escala portuária elegível.

# %%
df = pd.read_parquet(DATA_PATH)
df[DATE_COL] = pd.to_datetime(df[DATE_COL])

missing_required = [
    col for col in [DATE_COL, TARGET_H, PORT_LABEL_COL, *COMPONENT_COLUMNS.keys()]
    if col not in df.columns
]
assert not missing_required, f"Colunas obrigatórias ausentes: {missing_required}"

validation = pd.DataFrame([
    {"item": "Fonte analítica", "valor": relpath(DATA_PATH)},
    {"item": "Escalas portuárias", "valor": f"{len(df):,}".replace(",", ".")},
    {"item": "Menor data de chegada", "valor": df[DATE_COL].min().strftime("%d/%m/%Y %H:%M")},
    {"item": "Maior data de chegada", "valor": df[DATE_COL].max().strftime("%d/%m/%Y %H:%M")},
    {"item": "Número de portos", "valor": f"{df['port'].nunique():,}".replace(",", ".")},
    {"item": "% ausente no target", "valor": fmt_decimal_pt(df[TARGET_H].isna().mean() * 100, 2) + "%"},
    {"item": "Permanências negativas", "valor": int((df[TARGET_H].dropna() < 0).sum())},
])

assert len(df) == EXPECTED_N, f"Total observado ({len(df)}) difere do esperado ({EXPECTED_N})."
assert df[DATE_COL].min().normalize() == EXPECTED_START, "Data inicial diferente do período esperado."
assert df[DATE_COL].max().normalize() == EXPECTED_END, "Data final diferente do período esperado."
assert df[TARGET_H].notna().all(), "Há valores ausentes no target principal."
assert (df[TARGET_H] >= 0).all(), "Há valores negativos no target principal."

validation
# Out:
#                      item                            valor
# 0         Fonte analítica  data/processed/eda_base.parquet
# 1      Escalas portuárias                          129.625
# 2   Menor data de chegada                 01/01/2023 00:08
# 3   Maior data de chegada                 31/12/2025 23:00
# 4        Número de portos                              109
# 5     % ausente no target                            0,00%
# 6  Permanências negativas                                0

# %% [markdown]
# ## 3. Estatísticas exploratórias principais
#
# As estatísticas abaixo são recalculadas diretamente da base. Os valores em dias são usados como referência para a redação da monografia e para verificar consistência com a versão final do Capítulo 3.

# %%
main_stats = stats_for_series(df[TARGET_H])
reference_check = pd.DataFrame([
    {
        "estatística": "Média",
        "observado_d": main_stats["media_d"],
        "referência_d": REFERENCE_STATS_DAYS["media_d"],
        "diferença_d": main_stats["media_d"] - REFERENCE_STATS_DAYS["media_d"],
    },
    {
        "estatística": "Mediana",
        "observado_d": main_stats["mediana_d"],
        "referência_d": REFERENCE_STATS_DAYS["mediana_d"],
        "diferença_d": main_stats["mediana_d"] - REFERENCE_STATS_DAYS["mediana_d"],
    },
    {
        "estatística": "P90",
        "observado_d": main_stats["p90_d"],
        "referência_d": REFERENCE_STATS_DAYS["p90_d"],
        "diferença_d": main_stats["p90_d"] - REFERENCE_STATS_DAYS["p90_d"],
    },
    {
        "estatística": "P95",
        "observado_d": main_stats["p95_d"],
        "referência_d": REFERENCE_STATS_DAYS["p95_d"],
        "diferença_d": main_stats["p95_d"] - REFERENCE_STATS_DAYS["p95_d"],
    },
])

reference_check_display = reference_check.copy()
for col in ["observado_d", "referência_d", "diferença_d"]:
    reference_check_display[col] = reference_check_display[col].map(lambda x: fmt_decimal_pt(x, 3))

reference_check_display
# Out:
#   estatística observado_d referência_d diferença_d
# 0       Média       2,963        2,960       0,003
# 1     Mediana       1,601        1,600       0,001
# 2         P90       6,795        6,800      -0,005
# 3         P95      10,572       10,570       0,002

# %%
component_stats = pd.DataFrame([
    {"variável": label, **stats_for_series(df[col])}
    for col, label in COMPONENT_COLUMNS.items()
])

component_stats_display = component_stats[[
    "variável", "n", "media_h", "mediana_h", "p90_h", "p95_h", "p99_h",
    "media_d", "mediana_d", "p90_d", "p95_d", "p99_d",
]].copy()

for col in [c for c in component_stats_display.columns if c.endswith("_h")]:
    component_stats_display[col] = component_stats_display[col].map(lambda x: fmt_decimal_pt(x, 1))
for col in [c for c in component_stats_display.columns if c.endswith("_d")]:
    component_stats_display[col] = component_stats_display[col].map(lambda x: fmt_decimal_pt(x, 2))

component_stats_display
# Out:
#                 variável       n media_h mediana_h  p90_h  p95_h  p99_h  \
# 0  Espera para atracação  129625     8,5       0,0    6,7   38,4  223,6
# 1      Operação atracada  129625    61,9      34,8  139,3  210,9  453,6
# 2           Pós-operação  129625     0,7       0,0    0,0    0,0   12,7
# 3      Permanência total  129625    71,1      38,4  163,1  253,7  527,9
#
#   media_d mediana_d p90_d  p95_d  p99_d
# 0    0,35      0,00  0,28   1,60   9,32
# 1    2,58      1,45  5,81   8,79  18,90
# 2    0,03      0,00  0,00   0,00   0,53
# 3    2,96      1,60  6,80  10,57  21,99

# %% [markdown]
# ## 4. Figura - resumo estatístico da permanência
#
# Esta figura sintetiza os quatro números usados no texto para caracterizar a permanência total: média, mediana, P90 e P95. Os valores são recalculados a partir da base analítica final e apresentados em dias.

# %%
summary_points = pd.DataFrame(
    [
        {"estatística": "Média", "dias": main_stats["media_d"]},
        {"estatística": "Mediana", "dias": main_stats["mediana_d"]},
        {"estatística": "P90", "dias": main_stats["p90_d"]},
        {"estatística": "P95", "dias": main_stats["p95_d"]},
    ]
)

fig, ax = plt.subplots(figsize=(6.8, 3.4))
bars = ax.bar(
    summary_points["estatística"],
    summary_points["dias"],
    color=["#6f8796", COLOR_MEDIAN, COLOR_P90, "#9b5f4a"],
    width=0.62,
)

for bar, value in zip(bars, summary_points["dias"]):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.25,
        f"{fmt_decimal_pt(value, 2)} d",
        ha="center",
        va="bottom",
        fontsize=9,
    )

ax.set_ylabel("Dias")
ax.set_ylim(0, summary_points["dias"].max() * 1.18)
ax.grid(axis="y", color=COLOR_GRID, linewidth=0.7, alpha=0.9)
ax.yaxis.set_major_formatter(FuncFormatter(lambda value, pos: fmt_decimal_pt(value, 0)))

fig.tight_layout()
fig_resumo_pdf, fig_resumo_png = save_figure(fig, "cap3_eda_resumo_permanencia")

pd.DataFrame([{
    "figura": "Resumo estatístico da permanência",
    "pdf": relpath(fig_resumo_pdf),
    "png": relpath(fig_resumo_png),
}])
# Out:
#                               figura  \
# 0  Resumo estatístico da permanência
#
#                                                  pdf  \
# 0  outputs/capitulo3/cap3_eda_resumo_permanencia.pdf
#
#                                                  png
# 0  outputs/capitulo3/cap3_eda_resumo_permanencia.png

# %% [markdown]
# ## 5. Figura - distribuição da permanência e de seus componentes
#
# A visualização abaixo é limitada ao P99 apenas para leitura gráfica. Nenhuma observação é removida da base analítica nem dos cálculos das tabelas anteriores.

# %%
visual_limit_d = (df[TARGET_H] / 24).quantile(0.99)
bins = np.linspace(0, visual_limit_d, 55)

fig, axes = plt.subplots(2, 2, figsize=(7.2, 5.0), sharex=True)
axes = axes.ravel()

for ax, (col, label) in zip(axes, COMPONENT_COLUMNS.items()):
    values_d = df[col].dropna() / 24
    shown = values_d[values_d <= visual_limit_d]
    ax.hist(shown, bins=bins, color=COLOR_TOTAL, alpha=0.82, edgecolor="white", linewidth=0.35)
    median_d = values_d.median()
    p90_d = values_d.quantile(0.90)
    ax.axvline(median_d, color=COLOR_MEDIAN, linestyle="--", linewidth=1.2, label="Mediana")
    ax.axvline(p90_d, color=COLOR_P90, linestyle=":", linewidth=1.4, label="P90")
    ax.set_title(label)
    ax.set_xlim(0, visual_limit_d)
    ax.grid(axis="y", color=COLOR_GRID, linewidth=0.6, alpha=0.8)
    ax.xaxis.set_major_formatter(FuncFormatter(fmt_axis_days))

axes[0].set_ylabel("Escalas")
axes[2].set_ylabel("Escalas")
axes[2].set_xlabel("Dias")
axes[3].set_xlabel("Dias")
axes[0].legend(frameon=False, loc="upper right")

fig.tight_layout()
fig1_pdf, fig1_png = save_figure(fig, "cap3_eda_distribuicao_permanencia")

pd.DataFrame([{
    "figura": "Distribuição da permanência e componentes",
    "limite_visual_p99_d": fmt_decimal_pt(visual_limit_d, 2),
    "pdf": relpath(fig1_pdf),
    "png": relpath(fig1_png),
}])
# Out:
#                                       figura limite_visual_p99_d  \
# 0  Distribuição da permanência e componentes               21,99
#
#                                                  pdf  \
# 0  outputs/capitulo3/cap3_eda_distribuicao_perman...
#
#                                                  png
# 0  outputs/capitulo3/cap3_eda_distribuicao_perman...

# %% [markdown]
# ## 6. Figura - mapa dos portos brasileiros
#
# O mapa preserva o conceito da figura geográfica do EDA original: cada bolha representa um porto com coordenada disponível; o tamanho da bolha é proporcional ao volume de escalas e a cor representa o P90 da permanência total em dias.
#
# Para evitar poluição visual, todas as bolhas permanecem no mapa, mas apenas as 12 cidades-UF com maior volume de escalas recebem texto. Quando há mais de um porto na mesma cidade-UF, apenas o porto de maior volume define o rótulo visível daquela cidade. Os rótulos usam `Cidade - UF`, sem códigos de porto.

# %%
geo_required_columns = [
    "port",
    "port_call_id",
    "city",
    "state",
    "region",
    "latitude",
    "longitude",
    TARGET_H,
]
missing_geo_columns = [col for col in geo_required_columns if col not in df.columns]
assert not missing_geo_columns, f"Colunas geográficas ausentes: {missing_geo_columns}"

MIN_PORT_CALLS_FOR_MAP = 30
N_CITY_LABELS = 12

df_geo = df.dropna(subset=["port", "latitude", "longitude", TARGET_H]).copy()

port_geo_stats = (
    df_geo
    .groupby(["port", "city", "state", "region", "latitude", "longitude"], dropna=False)
    .agg(
        escalas=("port_call_id", "nunique"),
        mediana_h=(TARGET_H, "median"),
        p90_h=(TARGET_H, lambda s: s.quantile(0.90)),
    )
    .reset_index()
)
port_geo_stats["mediana_d"] = port_geo_stats["mediana_h"] / 24
port_geo_stats["p90_d"] = port_geo_stats["p90_h"] / 24
port_geo_stats["p90_menos_mediana_d"] = port_geo_stats["p90_d"] - port_geo_stats["mediana_d"]


def title_city(value):
    """Padroniza nomes de cidade sem transformar códigos de porto em rótulo."""
    connectors = {"da", "de", "do", "das", "dos", "e"}
    words = str(value).strip().lower().split()
    return " ".join(word if word in connectors else word.capitalize() for word in words)

port_geo_stats["cidade_uf"] = (
    port_geo_stats["city"].map(title_city) + " - " + port_geo_stats["state"].astype(str).str.upper()
)

port_geo_stats_map = port_geo_stats.loc[
    port_geo_stats["escalas"] >= MIN_PORT_CALLS_FOR_MAP
].copy()

city_labels = (
    port_geo_stats_map
    .sort_values("escalas", ascending=False)
    .drop_duplicates("cidade_uf")
    .head(N_CITY_LABELS)
    .copy()
)

map_validation = pd.DataFrame([
    {"item": "Escalas com coordenadas", "valor": f"{len(df_geo):,}".replace(",", ".")},
    {"item": "Portos com coordenadas", "valor": f"{df_geo['port'].nunique():,}".replace(",", ".")},
    {"item": "Portos no mapa", "valor": f"{len(port_geo_stats_map):,}".replace(",", ".")},
    {"item": "Filtro mínimo de volume", "valor": f"{MIN_PORT_CALLS_FOR_MAP} escalas por porto"},
    {"item": "Cidades rotuladas", "valor": f"{len(city_labels)} cidades-UF de maior volume"},
])

map_validation
# Out:
#                       item                          valor
# 0  Escalas com coordenadas                        129.625
# 1   Portos com coordenadas                            109
# 2           Portos no mapa                             91
# 3  Filtro mínimo de volume           30 escalas por porto
# 4        Cidades rotuladas  12 cidades-UF de maior volume

# %%
try:
    import geopandas as gpd
    import geobr
except ImportError as exc:
    raise ImportError(
        "A figura de mapa requer geopandas e geobr instalados no ambiente."
    ) from exc

br_states = geobr.read_state(year=2020)[
    ["abbrev_state", "name_state", "name_region", "geometry"]
].copy()

ports_gdf = gpd.GeoDataFrame(
    port_geo_stats_map.copy(),
    geometry=gpd.points_from_xy(port_geo_stats_map["longitude"], port_geo_stats_map["latitude"]),
    crs="EPSG:4326",
).to_crs(br_states.crs)

labels_gdf = gpd.GeoDataFrame(
    city_labels.copy(),
    geometry=gpd.points_from_xy(city_labels["longitude"], city_labels["latitude"]),
    crs="EPSG:4326",
).to_crs(br_states.crs)

bubble_size = (
    np.sqrt(ports_gdf["escalas"]) / np.sqrt(ports_gdf["escalas"].max()) * 620
)

fig, ax = plt.subplots(figsize=(7.2, 7.6))
br_states.plot(
    ax=ax,
    linewidth=0.45,
    edgecolor="#7c858c",
    facecolor="#f7f7f5",
)

ports_gdf.plot(
    ax=ax,
    markersize=bubble_size,
    column="p90_d",
    cmap="viridis",
    legend=True,
    alpha=0.78,
    edgecolor="white",
    linewidth=0.35,
    legend_kwds={
        "label": "P90 da permanência total (dias)",
        "shrink": 0.62,
    },
)

label_offsets = [
    (6, 4), (6, -6), (-6, 6), (-6, -6),
    (14, 0), (-14, 0), (0, 14), (0, -14),
    (20, 8), (20, -8), (-20, 8), (-20, -8),
    (30, 12), (30, -12), (-30, 12), (-30, -12),
]

placed_boxes = []
fig.canvas.draw()
renderer = fig.canvas.get_renderer()

for _, row in labels_gdf.iterrows():
    chosen_text = None
    chosen_box = None

    for dx, dy in label_offsets:
        candidate = ax.annotate(
            row["cidade_uf"],
            xy=(row.geometry.x, row.geometry.y),
            xytext=(dx, dy),
            textcoords="offset points",
            fontsize=7.4,
            ha="left" if dx >= 0 else "right",
            va="center",
            color="#222222",
        )
        candidate.set_path_effects([
            path_effects.Stroke(linewidth=2.2, foreground="white"),
            path_effects.Normal(),
        ])
        fig.canvas.draw()
        candidate_box = candidate.get_window_extent(renderer).expanded(1.03, 1.08)

        if not any(candidate_box.overlaps(box) for box in placed_boxes):
            chosen_text = candidate
            chosen_box = candidate_box
            break

        candidate.remove()

    if chosen_text is None:
        dx, dy = label_offsets[0]
        chosen_text = ax.annotate(
            row["cidade_uf"],
            xy=(row.geometry.x, row.geometry.y),
            xytext=(dx, dy),
            textcoords="offset points",
            fontsize=7.4,
            ha="left",
            va="center",
            color="#222222",
        )
        chosen_text.set_path_effects([
            path_effects.Stroke(linewidth=2.2, foreground="white"),
            path_effects.Normal(),
        ])
        fig.canvas.draw()
        chosen_box = chosen_text.get_window_extent(renderer).expanded(1.03, 1.08)

    placed_boxes.append(chosen_box)

ax.set_axis_off()
fig.tight_layout()
fig_mapa_pdf, fig_mapa_png = save_figure(fig, "cap3_eda_mapa_portos_p90")

pd.DataFrame([{
    "figura": "Mapa dos portos brasileiros",
    "portos_no_mapa": len(ports_gdf),
    "cidades_rotuladas": len(labels_gdf),
    "pdf": relpath(fig_mapa_pdf),
    "png": relpath(fig_mapa_png),
}])
# Out:
#                         figura  portos_no_mapa  cidades_rotuladas  \
# 0  Mapa dos portos brasileiros              91                 12
#
#                                               pdf  \
# 0  outputs/capitulo3/cap3_eda_mapa_portos_p90.pdf
#
#                                               png
# 0  outputs/capitulo3/cap3_eda_mapa_portos_p90.png

# %% [markdown]
# ## 7. Figura - heterogeneidade por tipo de operação
#
# Os tipos de operação são tratados como flags independentes `op_*`, preservando a natureza multirrótulo da base. Assim, uma mesma escala pode contribuir para mais de uma operação quando sua descrição operacional indicar múltiplos tipos.
#
# Para manter a figura legível, o boxplot exibe apenas operações com pelo menos 1% da base. A tabela de apoio abaixo mantém todas as operações mapeadas.

# %%
operation_columns = [col for col in df.columns if col.startswith("op_")]
operation_rows = []

for col in operation_columns:
    mask = df[col].fillna(False).astype(bool)
    values_d = df.loc[mask, TARGET_H] / 24
    operation_rows.append({
        "operação": OPERATION_LABELS.get(col, col.replace("op_", "").replace("_", " ").title()),
        "coluna": col,
        "escalas": int(mask.sum()),
        "percentual_base": mask.mean() * 100,
        "mediana_d": values_d.median(),
        "p90_d": values_d.quantile(0.90),
    })

operation_summary = pd.DataFrame(operation_rows).sort_values("escalas", ascending=False).reset_index(drop=True)
operation_summary_display = operation_summary.copy()
for col in ["percentual_base", "mediana_d", "p90_d"]:
    operation_summary_display[col] = operation_summary_display[col].map(lambda x: fmt_decimal_pt(x, 2))
operation_summary_display["escalas"] = operation_summary_display["escalas"].map(lambda x: f"{x:,}".replace(",", "."))

operation_summary_display[["operação", "escalas", "percentual_base", "mediana_d", "p90_d"]]
# Out:
#                                        operação escalas percentual_base  \
# 0                                         Carga  63.445           48,95
# 1                                      Descarga  57.279           44,19
# 2                                      Offshore  33.700           26,00
# 3                        Abastecimento (bunker)   3.780            2,92
# 4                    Desembarque de passageiros   2.484            1,92
# 5                       Embarque de passageiros   2.471            1,91
# 6                    Solicitação de certificado   1.885            1,45
# 7                                       Fundeio   1.305            1,01
# 8                                      Arribada     432            0,33
# 9                             Reparo/manutenção     317            0,24
# 10       Navio de Estado sem operação comercial     206            0,16
# 11  Retirada de resíduos sem operação comercial     202            0,16
# 12  Retirada de resíduos com operação comercial     193            0,15
# 13       Navio de Estado com operação comercial     190            0,15
# 14          Navio de Estado - Marinha do Brasil     188            0,15
# 15                         Fundeio ship-to-ship      97            0,07
# 16                 Tipo de operação não mapeado       0            0,00
#
#    mediana_d  p90_d
# 0       1,62   6,22
# 1       1,40   6,10
# 2       1,40   6,20
# 3       0,97   4,98
# 4       0,49   4,99
# 5       0,49   5,08
# 6       0,58   8,17
# 7       1,75  10,36
# 8       2,11   6,65
# 9       3,82  15,64
# 10      3,24   8,08
# 11      3,14   8,29
# 12      3,22   8,08
# 13      3,29   8,32
# 14      3,29   8,15
# 15      1,73   5,64
# 16

# %%
MIN_OPERATION_SHARE = 1.0
operation_plot = operation_summary[operation_summary["percentual_base"] >= MIN_OPERATION_SHARE].copy()
operation_plot = operation_plot.sort_values("p90_d", ascending=True).reset_index(drop=True)
operation_visual_limit_d = (df[TARGET_H] / 24).quantile(0.99)

boxplot_data = []
boxplot_labels = []
for _, row in operation_plot.iterrows():
    mask = df[row["coluna"]].fillna(False).astype(bool)
    values = (df.loc[mask, TARGET_H] / 24).clip(upper=operation_visual_limit_d)
    boxplot_data.append(values.to_numpy())
    boxplot_labels.append(row["operação"])

fig, ax = plt.subplots(figsize=(7.2, 5.4))
box = ax.boxplot(
    boxplot_data,
    vert=False,
    tick_labels=boxplot_labels,
    showfliers=False,
    patch_artist=True,
    widths=0.62,
    medianprops={"color": COLOR_MEDIAN, "linewidth": 1.5},
    boxprops={"facecolor": COLOR_BOX, "edgecolor": "#4f6570", "linewidth": 0.8},
    whiskerprops={"color": "#4f6570", "linewidth": 0.8},
    capprops={"color": "#4f6570", "linewidth": 0.8},
)

ax.set_xlabel("Permanência total (dias)")
ax.set_xlim(0, operation_visual_limit_d)
ax.xaxis.set_major_formatter(FuncFormatter(lambda value, pos: fmt_decimal_pt(value, 1)))
ax.grid(axis="x", color=COLOR_GRID, linewidth=0.7, alpha=0.9)

fig.tight_layout()
fig3_pdf, fig3_png = save_figure(fig, "cap3_eda_operacoes")

pd.DataFrame([{
    "figura": "Distribuição por tipo de operação",
    "operações_na_figura": len(operation_plot),
    "filtro_visual": f"operações com ao menos {fmt_decimal_pt(MIN_OPERATION_SHARE, 1)}% da base",
    "limite_visual_p99_d": fmt_decimal_pt(operation_visual_limit_d, 2),
    "pdf": relpath(fig3_pdf),
    "png": relpath(fig3_png),
}])
# Out:
#                               figura  operações_na_figura  \
# 0  Distribuição por tipo de operação                    8
#
#                          filtro_visual limite_visual_p99_d  \
# 0  operações com ao menos 1,0% da base               21,99
#
#                                         pdf  \
# 0  outputs/capitulo3/cap3_eda_operacoes.pdf
#
#                                         png
# 0  outputs/capitulo3/cap3_eda_operacoes.png

# %% [markdown]
# ## 8. Resumo dos outputs
#
# Os arquivos abaixo são os artefatos finais esperados para inserção no Capítulo 3. Quando o repositório da monografia existir como diretório irmão, os PDFs também serão copiados para `../mba-tcc-monografia/USPSC-img/`.

# %%
figure_outputs = pd.DataFrame([
    {
        "figura": "cap3_eda_resumo_permanencia",
        "caminho_pdf": relpath(fig_resumo_pdf),
        "caminho_png": relpath(fig_resumo_png),
        "objetivo": "Destacar média, mediana, P90 e P95 da permanência total.",
    },
    {
        "figura": "cap3_eda_distribuicao_permanencia",
        "caminho_pdf": relpath(fig1_pdf),
        "caminho_png": relpath(fig1_png),
        "objetivo": "Evidenciar assimetria, longa cauda e decomposição da permanência.",
    },
    {
        "figura": "cap3_eda_mapa_portos_p90",
        "caminho_pdf": relpath(fig_mapa_pdf),
        "caminho_png": relpath(fig_mapa_png),
        "objetivo": "Evidenciar localização dos portos, volume de escalas e P90 da permanência.",
    },
    {
        "figura": "cap3_eda_operacoes",
        "caminho_pdf": relpath(fig3_pdf),
        "caminho_png": relpath(fig3_png),
        "objetivo": "Evidenciar heterogeneidade por tipos de operação multirrótulo.",
    },
])

figure_outputs["pdf_existe"] = figure_outputs["caminho_pdf"].map(lambda p: (PROJECT_ROOT / p).exists())
figure_outputs["png_existe"] = figure_outputs["caminho_png"].map(lambda p: (PROJECT_ROOT / p).exists())

copied_to_monografia = []
if MONOGRAFIA_IMG_DIR.exists():
    for pdf_path in [fig_resumo_pdf, fig1_pdf, fig_mapa_pdf, fig3_pdf]:
        destination = MONOGRAFIA_IMG_DIR / pdf_path.name
        shutil.copy2(pdf_path, destination)
        copied_to_monografia.append(destination.as_posix())

if copied_to_monografia:
    print("PDFs copiados para o repositório da monografia:")
    for path in copied_to_monografia:
        print(f"- {path}")
else:
    print("Repositório irmão mba-tcc-monografia/USPSC-img não encontrado; PDFs mantidos apenas em outputs/capitulo3/.")

figure_outputs
# Out:
# Repositório irmão mba-tcc-monografia/USPSC-img não encontrado; PDFs mantidos apenas em outputs/capitulo3/.
#                               figura  \
# 0        cap3_eda_resumo_permanencia
# 1  cap3_eda_distribuicao_permanencia
# 2           cap3_eda_mapa_portos_p90
# 3                 cap3_eda_operacoes
#
#                                          caminho_pdf  \
# 0  outputs/capitulo3/cap3_eda_resumo_permanencia.pdf
# 1  outputs/capitulo3/cap3_eda_distribuicao_perman...
# 2     outputs/capitulo3/cap3_eda_mapa_portos_p90.pdf
# 3           outputs/capitulo3/cap3_eda_operacoes.pdf
#
#                                          caminho_png  \
# 0  outputs/capitulo3/cap3_eda_resumo_permanencia.png
# 1  outputs/capitulo3/cap3_eda_distribuicao_perman...
# 2     outputs/capitulo3/cap3_eda_mapa_portos_p90.png
# 3           outputs/capitulo3/cap3_eda_operacoes.png
#
#                                             objetivo  pdf_existe  png_existe
# 0  Destacar média, mediana, P90 e P95 da permanên...        True        True
# 1  Evidenciar assimetria, longa cauda e decomposi...        True        True
# 2  Evidenciar localização dos portos, volume de e...        True        True
# 3  Evidenciar heterogeneidade por tipos de operaç...        True        True
